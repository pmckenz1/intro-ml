# %% [markdown]
# ## Import our new module

# %%
import simcat     ## imported from current dir ./simcat/__init__.py
import toytree    ## requires github Master branch currently
import toyplot
from dendropy.simulate import treesim  ## would be nice to replace this with toytree sims...

# %% [markdown]
# ### It has two class objects

# %%
print simcat.Model
print simcat.DataBase
# Out:
# <class 'simcat.simcat.Model'>
# <class 'simcat.simcat.DataBase'>

# %% [markdown]
# ### The `simcat.Model` object
# This class is used to simulate count matrices for a given tree with provided admixture events. Trees are entered as either newick strings or as Toytree objects. Adding the `debug=True` argument prints more info about the generated data set.

# %%
## generate a random tree
tree = toytree.rtree(4)
tree.tree.convert_to_ultrametric()
tree.draw(tree_style='c', node_labels='idx', tip_labels=False);
# Out:
# <div class="toyplot" id="t3a4d00479f5a407fb425c37d2c679c39" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="225.0px" id="t41162ab85c3648e3b4faf4e0fee4fbed" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 275.0 225.0" width="275.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t4fcce868804a4b95ad475c8866965ab8"><clipPath id="t1490e29ea4e14af8879aa12d6b29b728"><rect height="225.0" width="275.0" x="0.0" y="0.0"></rect></clipPath><g clip-path="url(#t1490e29ea4e14af8879aa12d6b29b728)"><g class="toyplot-mark-Text" id="taff5be1bac6b47e2b642bae904d42bf9"><g class="toyplot-Series"></g></g><g class="toyplot-mark-Graph" id="t51b1effc95704b1da40c18cfa7d6bd30"><g class="toyplot-Edges"><path d="M 173.958333333 50.0 L 225.0 175.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 122.916666667 91.6666666667 L 166.666666667 175.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 79.1666666667 133.333333333 L 108.333333333 175.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 79.1666666667 133.333333333 L 50.0 175.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 122.916666667 91.6666666667 L 79.1666666667 133.333333333" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 173.958333333 50.0 L 122.916666667 91.6666666667" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><g class="toyplot-HeadMarkers"></g><g class="toyplot-MiddleMarkers"></g><g class="toyplot-TailMarkers"></g></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.0, 175.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(108.33333333333334, 175.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(166.66666666666666, 175.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(225.0, 175.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(79.166666666666671, 133.33333333333334)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(122.91666666666666, 91.666666666666671)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(173.95833333333334, 50.0)"><circle r="0.0"></circle></g></g></g><g class="toyplot-mark-Scatterplot" id="t60a52a41462e4187b4096267cf0f1159"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(50.0, 175.0)"><title>idx: 0
# name: t-3
# dist: 1
# support: 100
# height: 0</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">0</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(108.33333333333334, 175.0)"><title>idx: 1
# name: t-2
# dist: 1
# support: 100
# height: 0</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">1</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(166.66666666666666, 175.0)"><title>idx: 2
# name: t-1
# dist: 2
# support: 100
# height: 0</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">2</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(225.0, 175.0)"><title>idx: 3
# name: t-0
# dist: 3
# support: 100
# height: 0</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">3</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(79.166666666666671, 133.33333333333334)"><title>idx: 4
# name: i4
# dist: 1
# support: 1
# height: 1</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">4</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(122.91666666666666, 91.666666666666671)"><title>idx: 5
# name: i5
# dist: 1
# support: 1
# height: 2</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">5</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(173.95833333333334, 50.0)"><title>idx: 6
# name: i6
# dist: 0
# support: 100
# height: 3</title><circle r="11.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-2.502" y="2.2995">6</text></g></g></g></g></g></g></svg><div class="toyplot-behavior"><script>(function()
# {
# var modules={};
# modules["toyplot/tables"] = (function()
#     {
#         var tables = [];
#
#         var module = {};
#
#         module.set = function(owner, key, names, columns)
#         {
#             tables.push({owner: owner, key: key, names: names, columns: columns});
#         }
#
#         module.get = function(owner, key)
#         {
#             for(var i = 0; i != tables.length; ++i)
#             {
#                 var table = tables[i];
#                 if(table.owner != owner)
#                     continue;
#                 if(table.key != key)
#                     continue;
#                 return {names: table.names, columns: table.columns};
#             }
#         }
#
#         module.get_csv = function(owner, key)
#         {
#             var table = module.get(owner, key);
#             if(table != undefined)
#             {
#                 var csv = "";
#                 csv += table.names.join(",") + "\n";
#                 for(var i = 0; i != table.columns[0].length; ++i)
#                 {
#                   for(var j = 0; j != table.columns.l

# %%
## simulate counts for a tree with no admixture
m1 = simcat.Model(tree, ntests=3, debug=True)
m1.run()
m1.counts.shape
# Out:
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# (3, 16, 16)

# %%
## simulate counts for a tree with one admixture edge [2->1, interval 0.2-0.5, rate 0.1]
m2 = simcat.Model(tree, admixture_edges=[(2, 1, 0.2, 0.5, 0.1)], ntests=3, debug=True)
m2.run()
m2.counts.shape
# Out:
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (0.20000000000000001, 0.5, 0.10000000000000001, (2, 1))
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (0.20000000000000001, 0.5, 0.10000000000000001, (2, 1))
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (0.20000000000000001, 0.5, 0.10000000000000001, (2, 1))
# (3, 16, 16)

# %%
## simulate counts for 'ntests' admix events uniformly spread across the edge [2->1]
m3 = simcat.Model(tree, admixture_edges=[(2, 1, None, None, None)], ntests=3, debug=True)
m3.run()
m3.counts.shape
# Out:
# uniform testvals mig: (0, 200000) (0.0, 0.5)
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (40912, 113545, 0.46480804640857393, (2, 1))
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (119108, 192902, 0.15818777729089295, (2, 1))
#
# demog div: (600000, 3, 0)
# demog div: (400000, 2, 0)
# demog div: (200000, 1, 0)
# demog mig: (130635, 149781, 0.091959405838547226, (2, 1))
# (3, 16, 16)

# %% [markdown]
# ### Generate a list of trees to pass to `simcat.Model`
# Here it would be nice to have simple functions to generate species trees with branch length distributions according to different processes (e.g., coalescent, Yule, b-d), and input parameters for those models.

# %%
## generate a list of 1000 birth-death trees
simtrees = []
tt = []
while len(simtrees) < 10:
    try:
        ## generate tree
        stree = treesim.discrete_birth_death_tree(birth_rate=0.1, death_rate=0.01, ntax=4)
        
        ## convert to newick
        snewick = stree.as_string('newick', suppress_rooting=True)
        
        ## store if it has 4 tips (not sure why dendropy returns 5 tips sometimes)
        if len(toytree.tree(snewick)) == 4:
            simtrees.append(snewick)
    except Exception: 
        pass

# %%
## plot a couple of random b-d trees with node heights
ntrees = 4
canvas = toyplot.Canvas(width=800, height=200)
axes = [canvas.cartesian(grid=(1, ntrees, idx)) for idx in range(ntrees)]
for i in range(ntrees):
    ax = axes[i]
    ax.show = False
    toytree.tree(simtrees[i]).draw(
        axes=ax, tree_style='c', node_labels='name', tip_labels=False, node_size=16)
# Out:
# <div class="toyplot" id="t16aca9fc292c4d7d837fbce1a6473a0f" style="text-align:center"><svg class="toyplot-canvas-Canvas" height="200.0px" id="te88a98a7841646a98362928979cc56d8" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" viewBox="0 0 800.0 200.0" width="800.0px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink"><g class="toyplot-coordinates-Cartesian" id="t1a2fd342069f4ba9882085c82f89b12f"><clipPath id="tcceade7e0f974774b00db695ef759055"><rect height="120.0" width="120.0" x="40.0" y="40.0"></rect></clipPath><g clip-path="url(#tcceade7e0f974774b00db695ef759055)"><g class="toyplot-mark-Text" id="t6a2c3de04ca349f5bd46bb3c17c9669d"><g class="toyplot-Series"></g></g><g class="toyplot-mark-Graph" id="t5b1342e95b3846019de08d530b76201f"><g class="toyplot-Edges"><path d="M 133.333333333 65.0 L 150.0 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 133.333333333 65.0 L 116.666666667 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 100.0 50.0 L 133.333333333 65.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 66.6666666667 55.0 L 83.3333333333 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 66.6666666667 55.0 L 50.0 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 100.0 50.0 L 66.6666666667 55.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><g class="toyplot-HeadMarkers"></g><g class="toyplot-MiddleMarkers"></g><g class="toyplot-TailMarkers"></g></g><g class="toyplot-Vertices"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(50.0, 150.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(83.333333333333343, 150.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(116.66666666666667, 150.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(150.0, 150.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(66.666666666666671, 55.000000000000007)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(133.33333333333334, 65.0)"><circle r="0.0"></circle></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:rgb(40%,76.1%,64.7%);stroke-opacity:1.0" transform="translate(100.0, 50.0)"><circle r="0.0"></circle></g></g></g><g class="toyplot-mark-Scatterplot" id="t1cd6b2845e61455b823d7973698f2c5b"><g class="toyplot-Series"><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(50.0, 150.0)"><title>idx: 0
# name: T4
# dist: 19
# support: 100
# height: 0</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-5.2515" y="2.2995">T4</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(83.333333333333343, 150.0)"><title>idx: 1
# name: T3
# dist: 19
# support: 100
# height: 0</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-5.2515" y="2.2995">T3</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(116.66666666666667, 150.0)"><title>idx: 2
# name: T2
# dist: 17
# support: 100
# height: 0</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-5.2515" y="2.2995">T2</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(150.0, 150.0)"><title>idx: 3
# name: T1
# dist: 17
# support: 100
# height: 0</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-5.2515" y="2.2995">T1</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(66.666666666666671, 55.000000000000007)"><title>idx: 4
# name: i4
# dist: 1
# support: 100
# height: 19</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-3.501" y="2.2995">i4</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(133.33333333333334, 65.0)"><title>idx: 5
# name: i5
# dist: 3
# support: 100
# height: 17</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-3.501" y="2.2995">i5</text></g></g><g class="toyplot-Datum" style="fill:rgb(40%,76.1%,64.7%);fill-opacity:1.0;opacity:1.0;stroke:none" transform="translate(100.0, 50.0)"><title>idx: 6
# name: i6
# dist: 17
# support: 100
# height: 20</title><circle r="8.0"></circle><g><text style="fill:rgb(14.9%,14.9%,14.9%);fill-opacity:1.0;font-family:helvetica;font-size:9.0px;font-weight:normal;stroke:none;vertical-align:baseline;white-space:pre" x="-3.501" y="2.2995">i6</text></g></g></g></g></g></g><g class="toyplot-coordinates-Cartesian" id="tcb5926f54ce24332aa0577ea4ae8de52"><clipPath id="tabcaa14624c64bbbb2862a6d7f505528"><rect height="120.0" width="120.0" x="240.0" y="40.0"></rect></clipPath><g clip-path="url(#tabcaa14624c64bbbb2862a6d7f505528)"><g class="toyplot-mark-Text" id="t1db2a87e286c422aba0c08352c94d95d"><g class="toyplot-Series"></g></g><g class="toyplot-mark-Graph" id="tf8298d29cf9b45b69ad6127fb719f5e9"><g class="toyplot-Edges"><path d="M 320.833333333 50.0 L 350.0 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 291.666666667 90.0 L 316.666666667 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 266.666666667 100.0 L 283.333333333 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 266.666666667 100.0 L 250.0 150.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:round;stroke-opacity:1.0;stroke-width:2"></path><path d="M 291.666666667 90.0 L 266.666666667 100.0" style="fill:none;stroke:rgb(16.1%,15.3%,14.1%);stroke-linecap:r

# %% [markdown]
# ## The `simcat.DataBase` object
#
# The `DataBase` object, in development, could take the list of generated trees and loop over all trees and edges on those trees, and then call `simcat.Model` to sample a range of admixture events on those edges and generate count matrices. The main job of the `DataBase` object is to parallelize all of those simulations and store the results. The results should be stored in a HDF5 database with metadata about the params of the test.

# %%
## init a database
db1 = simcat.DataBase(name="test-1")

# %% [markdown]
# The `DataBase` object should perform a loop somewhat like below...

# %%
## iterate across trees
for sidx in xrange(len(simtrees)):
    
    ## iterate across possible admixture edges
    ttree = toytree.tree(simtrees[sidx])
    for edge in simcat.get_all_admix_edges(ttree):
        
        ## create model object to sim: 1000 SNPS, 10 tests with admixture uniformly
        ## sampled across the selected edge length and with rate in U(0, 0.5)
        carr = simcat.Model(
            ttree, 
            admixture_edges=(edge[0], edge[1], None, None, None),
            ntests=10)
        
        ## run model to get counts and save array to HDF5
        carr.run()
        
        ## print to stdout some info about this run
        label = ("tree {}; {}->{}; {} snps; {} tests".format(
            sidx, edge[0], edge[1], carr.nsnps, carr.ntests))
        print label
        
        ## store the results
        ## .. hdf5 store array and info as metadata
# Out:
# tree 0; 1->2; 1000 snps; 10 tests
# tree 0; 0->1; 1000 snps; 10 tests
# tree 0; 5->4; 1000 snps; 10 tests
# tree 0; 1->3; 1000 snps; 10 tests
# tree 0; 0->5; 1000 snps; 10 tests
# tree 0; 2->0; 1000 snps; 10 tests
# tree 0; 4->5; 1000 snps; 10 tests
# tree 0; 3->1; 1000 snps; 10 tests
# tree 0; 3->2; 1000 snps; 10 tests
# tree 0; 2->1; 1000 snps; 10 tests
# tree 0; 0->2; 1000 snps; 10 tests
# tree 0; 3->0; 1000 snps; 10 tests
# tree 0; 2->3; 1000 snps; 10 tests
# tree 0; 5->0; 1000 snps; 10 tests
# tree 0; 5->1; 1000 snps; 10 tests
# tree 0; 1->0; 1000 snps; 10 tests
# tree 0; 0->3; 1000 snps; 10 tests
# tree 0; 1->5; 1000 snps; 10 tests
# tree 1; 1->2; 1000 snps; 10 tests
# tree 1; 0->1; 1000 snps; 10 tests
# tree 1; 3->2; 1000 snps; 10 tests
# tree 1; 1->3; 1000 snps; 10 tests
# tree 1; 0->3; 1000 snps; 10 tests
# tree 1; 3->0; 1000 snps; 10 tests
# tree 1; 3->1; 1000 snps; 10 tests
# tree 1; 2->1; 1000 snps; 10 tests
# tree 1; 0->2; 1000 snps; 10 tests
# tree 1; 2->0; 1000 snps; 10 tests
# tree 1; 2->3; 1000 snps; 10 tests
# tree 1; 4->3; 1000 snps; 10 tests
# tree 1; 4->2; 1000 snps; 10 tests
# tree 1; 1->0; 1000 snps; 10 tests
# tree 1; 3->5; 1000 snps; 10 tests
# tree 1; 3->4; 1000 snps; 10 tests
# tree 1; 2->4; 1000 snps; 10 tests
# tree 1; 5->3; 1000 snps; 10 tests
# tree 2; 3->2; 1000 snps; 10 tests
# tree 2; 2->3; 1000 snps; 10 tests
# tree 2; 4->3; 1000 snps; 10 tests
# tree 2; 4->2; 1000 snps; 10 tests
# tree 2; 3->5; 1000 snps; 10 tests
# tree 2; 3->4; 1000 snps; 10 tests
# tree 2; 2->4; 1000 snps; 10 tests
# tree 2; 5->3; 1000 snps; 10 tests
# tree 3; 1->2; 1000 snps; 10 tests
# tree 3; 0->1; 1000 snps; 10 tests
# tree 3; 3->2; 1000 snps; 10 tests
# tree 3; 1->3; 1000 snps; 10 tests
# tree 3; 0->3; 1000 snps; 10 tests
# tree 3; 3->0; 1000 snps; 10 tests
# tree 3; 3->1; 1000 snps; 10 tests
# tree 3; 2->1; 1000 snps; 10 tests
# tree 3; 0->2; 1000 snps; 10 tests
# tree 3; 2->0; 1000 snps; 10 tests
# tree 3; 2->3; 1000 snps; 10 tests
# tree 3; 4->3; 1000 snps; 10 tests
# tree 3; 4->2; 1000 snps; 10 tests
# tree 3; 1->0; 1000 snps; 10 tests
# tree 3; 3->5; 1000 snps; 10 tests
# tree 3; 3->4; 1000 snps; 10 tests
# tree 3; 2->4; 1000 snps; 10 tests
# tree 3; 5->3; 1000 snps; 10 tests
# tree 4; 3->2; 1000 snps; 10 tests
# tree 4; 2->3; 1000 snps; 10 tests
# tree 4; 4->3; 1000 snps; 10 tests
# tree 4; 4->2; 1000 snps; 10 tests
# tree 4; 3->5; 1000 snps; 10 tests
# tree 4; 3->4; 1000 snps; 10 tests
# tree 4; 2->4; 1000 snps; 10 tests
# tree 4; 5->3; 1000 snps; 10 tests
# tree 5; 3->2; 1000 snps; 10 tests
# tree 5; 2->3; 1000 snps; 10 tests
# tree 5; 4->3; 1000 snps; 10 tests
# tree 5; 4->2; 1000 snps; 10 tests
# tree 5; 3->5; 1000 snps; 10 tests
# tree 5; 3->4; 1000 snps; 10 tests
# tree 5; 2->4; 1000 snps; 10 tests
# tree 5; 5->3; 1000 snps; 10 tests
# tree 6; 1->2; 1000 snps; 10 tests
# tree 6; 0->1; 1000 snps; 10 tests
# tree 6; 5->4; 1000 snps; 10 tests
# tree 6; 1->3; 1000 snps; 10 tests
# tree 6; 0->3; 1000 snps; 10 tests
# tree 6; 2->0; 1000 snps; 10 tests
# tree 6; 4->5; 1000 snps; 10 tests
# tree 6; 3->1; 1000 snps; 10 tests
# tree 6; 3->2; 1000 snps; 10 tests
# tree 6; 2->1; 1000 snps; 10 tests
# tree 6; 0->2; 1000 snps; 10 tests
# tree 6; 3->0; 1000 snps; 10 tests
# tree 6; 2->3; 1000 snps; 10 tests
# tree 6; 4->3; 1000 snps; 10 tests
# tree 6; 4->2; 1000 snps; 10 tests
# tree 6; 1->0; 1000 snps; 10 tests
# tree 6; 3->4; 1000 snps; 10 tests
# tree 6; 2->4; 1000 snps; 10 tests
# tree 7; 1->2; 1000 snps; 10 tests
# tree 7; 0->1; 1000 snps; 10 tests
# tree 7; 3->2; 1000 snps; 10 tests
# tree 7; 1->3; 1000 snps; 10 tests
# tree 7; 0->3; 1000 snps; 10 tests
# tree 7; 3->0; 1000 snps; 10 tests
# tree 7; 3->1; 1000 snps; 10 tests
# tree 7; 2->1; 1000 snps; 10 tests
# tree 7; 0->2; 1000 snps; 10 tests
# tree 7; 2->0; 1000 snps; 10 tests
# tree 7; 2->3; 1000 snps; 10 tests
# tree 7; 4->3; 1000 snps; 10 tests
# tree 7; 4->2; 1000 snps; 10 tests
# tree 7; 1->0; 1000 snps; 10 tests
# tree 7; 3->5; 1000 snps; 10 tests
# tree 7; 3->4; 1000 snps; 10 tests
# tree 7; 2->4; 1000 snps; 10 tests
# tree 7; 5->3; 1000 snps; 10 tests
# tree 8; 1->2; 1000 snps; 10 tests
# tree 8; 0->1; 1000 snps; 10 tests
# tree 8; 5->4; 1000 snps; 10 tests
# tree 8; 1->3; 1000 snps; 10 tests
# tree 8; 0->5; 1000 snps; 10 tests
# tree 8; 2->0; 1000 snps; 10 tests
# tree 8; 4->5; 1000 snps; 10 tests
# tree 8; 3->1; 1000 snps; 10 tests
# tree 8; 3->2; 1000 snps; 10 tests
# tree 8; 2->1; 1000 snps; 10 tests
# tree 8; 0->2; 1000 snps; 10 tests
# tree 8; 3->0; 1000 snps; 10 tests
# tree 8; 2->3; 1000 snps; 10 tests
# tree 8; 5->0; 1000 snps; 10 tests
# tree 8; 5->1; 1000 snps; 10 tests
# tree 8; 1->0; 1000 snps; 10 tests
# tree 8; 0->3; 1000 snps; 10 tests
# tree 8; 1->5; 1000 snps; 10 tests
# tree 9; 1->2; 1000 snps; 10 tests
# tree 9; 0->1; 1000 snps; 10 tests
# tree 9; 5->4; 1000 snps; 10 tests
# tree 9; 1->3; 1000 snps; 10 tests
# tree 9; 0->5; 1000 snps; 10 tests
# tree 9; 2->0; 1000 snps; 10 tests
# tree 9; 4->5; 1000 snps; 10 tests
# tree 9; 3->1; 1000 snps; 10 tests
# tree 9; 3->2; 1000 snps; 10 tests
# tree 9; 2->1; 1000 snps; 10 tests
# tree 9; 0->2; 1000 snps; 10 tests
# tree 9; 3->0; 1000 snps; 10 tests
# tree 9; 2->3; 1000 snps; 10 tests
# tree 9; 5->0; 1000 snps; 10 tests
# tree 9; 5->1; 1000 snps; 10 tests
# tree 9; 1->0; 1000 snps; 10 tests
# tree 9; 0->3; 1000 snps; 10 tests
# tree 9; 1->5; 1000 snps; 10 tests
